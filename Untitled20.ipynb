# %% [markdown]
# <a href="https://colab.research.google.com/github/kostikixum/DZ3/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Дизайн эксперемента 1
# **Гипотеза:** Внедрение ускоренной покупки в онлфн магазине OZON увеличит конверсию и улучшит общее восприятие процесса совершения покупок.
#
# **Аудитория :** Размер выборки для каждой группы должен быть достаточным для статистической значимости (рекомендуется провести априорный анализ мощности).
#
# **Группа A (Контрольная группа):** Пользователи, совершающие стандартную покупку
#
# **Группа B (Экспериментальная группа):**Пользователи, совершающие ускоренную покупку.
#
# **Длитльность:** Эксперимент будет проводиться в течение 4 недель с момента внедрения ускоренного процесса покупки.
#
# **Конверсия:** Сравнение процента завершенных покупок между двумя группами.
#
# **Время Совершения Покупки:** Среднее время, затраченное на завершение покупки.
#
# **Удовлетворенность Пользователей:** Оценка удовлетворенности пользователей с использованием анкеты после покупки.
#
# **Количество Отказов:** Количество случаев, когда пользователи прервали процесс покупки.
#
# >**Анализ** Группе B будет предложен ускоренный процесс покупки, который будет включать в себя минимизацию шагов, дополнительные средства авторизации, и/или автоматизированные функции для ускорения совершения покупки. Случайное назначение пользователей в группы A и B.Запуск ускоренного процесса покупки для группы B. Сбор данных о конверсии, времени покупки, удовлетворенности и отказах. Анализ результатов и сравнение метрик между группами A и B.

# %% [markdown]
# ##Дизайн эксперемента 2
# **Гипотеза:** Скидка в процентах может быть более мотивирующей для покупателей, так как величина скидки будет зависеть от стоимости товара.Структура сайта и предложение товаров должны оставаться неизменными.
# Рекламные активности на обеих группах должны быть сопоставимыми.
# Скидка в рублях может создать более наглядное впечатление о выгоде, особенно для товаров с более высокой стоимостью.
# Аудитория : Размер выборки для каждой группы должен быть достаточным для статистической значимости (рекомендуется провести априорный анализ мощности).
#
# **Группа A (Контрольная группа):** Предлагается скидка в рублях.
#
# **Группа B (Экспериментальная группа):**Предлагается скидка в процентах
#
# **Длитльность:** Эксперимент будет проводиться в течение 4 недель с момента внедрения ускоренного процесса покупки.
#
# **Конверсия:** тношение количества совершенных покупок к количеству посещений сайта.
#
# **Дополнительные Измерения:** Средний чек, уровень отказов, отзывы клиентов.
#
# > **Анализ** Использование статистических методов (например, t-тест) для оценки значимости различий между группами..Анализ данных по истечении эксперимента и формирование выводов.
