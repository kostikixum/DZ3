# %% [markdown]
# <a href="https://colab.research.google.com/github/kostikixum/DZ3/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Условие 1: Задача 1
# ###Постройте график ,Назовите график ,Сделайте именование оси x и оси y ,Сделайте выводы

# %% [markdown]
# ### 1.1. Скачать следующие данные: kc-house-data и laptop_price

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_hous = pd.read_csv(' https://gbcdn.mrgcdn.ru/uploads/asset/5349842/attachment/16ab1213a48b859e6e5e7407e10933ff.csv ' )
df_hous.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df_laptop = pd.read_csv('laptop_price.csv',encoding = "ISO-8859-1")
df_laptop.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %% [markdown]
# #### 1.2. Изучите стоимости недвижимости

# %%
df_hous['price'].min(), df_hous['price'].max(),df_hous['price'].median(),
# Out:
# (75000.0, 7700000.0, 450000.0)

# %%
plt.hist(df_hous['price'])
plt.title('Распределение стоимости')
plt.xlabel('euro *1000000')
plt.ylabel('Количество');

# %% [markdown]
# #### Вывод : Большинство домов стоимостью до 1 милиона единиц

# %% [markdown]
# #### 1.3. Изучите распределение квадратуры жилой

# %%
plt.hist(df_hous['sqft_living'])
plt.title('Распределение квадратуры жилой ')
plt.xlabel('Квадраты')
plt.ylabel('Количество');

# %% [markdown]
# #### Вывод : большинство домов имеют площадь больше 2000 кадратных футов

# %% [markdown]
# #### 1.4. Изучите распределение года постройки

# %%
plt.hist(df_hous['yr_built'])
plt.title('Распределение  года постройки ')
plt.xlabel('Год')
plt.ylabel('Количество');

# %% [markdown]
# #### Вывод : Большинство домов были построены после 1940г

# %% [markdown]
# ## Условие 2: 2 задача
# #### 2.1. Изучите распределение домов от наличия вида на набережную

# %%
data = df_hous['waterfront'].value_counts()
data
names = data.index
values = data.values
plt.pie(values, autopct='%.1f%%', labels=names);

# %% [markdown]
# #### Вывод : только 0,8% имеют вид на набережную

# %% [markdown]
# #### 2.2. Изучите распределение этажей домов

# %%
data = df_hous['floors'].value_counts()
data
names = data.index
values = data.values
plt.pie(values, autopct='%.1f%%', labels=names);

# %% [markdown]
# #### Вывод : 49,4% домов однаэтжные

# %% [markdown]
# ### 2.3. Изучите распределение состояния домов

# %%
plt.hist(df_hous['yr_renovated'])
plt.title('распределение состояния домов')
plt.xlabel('Год')
plt.ylabel('Количество');

# %%
df_hous['house age'] =2023- df_hous['yr_built']
df_hous.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode      lat  \
# 0      5650     1.0           0     0  ...             0    98178  47.5112
# 1      7242     2.0           0     0  ...          1991    98125  47.7210
# 2     10000     1.0           0     0  ...             0    98028  47.7379
# 3      5000     1.0           0     0  ...             0    98136  47.5208
# 4      8080     1.0           0     0  ...             0    98074  47.6168
#
# ...

# %%
plt.hist(df_hous['house age'])
plt.title('распределение состояния домов')
plt.xlabel('Возраст')
plt.ylabel('Количество');

# %% [markdown]
# ## Условие 3: 3 задача
# ### Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
plt.figure(figsize=(10, 6))
plt.bar(df_hous['house age'], df_hous['price'])
plt.title('Возраст\цена')
plt.xlabel('Возраст')
plt.ylabel('Цена')
plt.legend(['Возраст'])
plt.xticks(rotation=50);

# %%
plt.figure(figsize=(15, 6))
plt.bar(df_hous['bedrooms'], df_hous['price'], width=w)
plt.bar(df_hous['bathrooms'], df_hous['price'], width=w)
plt.bar(df_hous['floors'], df_hous['price'], width=w)
plt.title('Удобства\цена')
plt.xlabel('Количество')
plt.ylabel('Цена')
plt.legend(['Спальня','Ванная','Этажи'])
plt.xticks(rotation=50);

# %%
plt.figure(figsize=(8, 3))
plt.bar(df_hous['sqft_lot'], df_hous['sqft_living'])
plt.title('Площадь\цена')
plt.xlabel('Площадь')
plt.ylabel('Цена')
plt.legend(['Жидая площадь','Общая'])
plt.xticks(rotation=50);

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_hous['sqft_lot'], y=df_hous['sqft_living'])
plt.xlabel('Цена')
plt.ylabel('Море')
plt.title('Зависимость цены от вида');

# %%
cols=['bedrooms','bathrooms','floors','price','grade','waterfront']
g=sns.PairGrid(df_hous[cols])
g.map(sns.scatterplot)
